# %%
import numpy as np
with open("backend/images/glass.jpg", "rb") as image:
  f = np.array(bytearray(image.read()),dtype=np.uint8)

# %%
len(f)
# Out:
# 230368

# %%
f[0:16]
# Out:
# array([255, 216, 255, 224,   0,  16,  74,  70,  73,  70,   0,   1,   1,
#          0,   0,   1], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Ghost\Desktop\Face_Filter\test.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Ghost/Desktop/Face_Filter/test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> plt.imshow(f)
#
# File c:\Users\Ghost\anaconda3\envs\class\lib\site-packages\matplotlib\_api\deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# ...

# %%
import PIL.Image as Image
import io
import cv2

# %%
image= Image.open(io.BytesIO(f)).convert('RGB')
glass_array=cv2.cvtColor(np.array(image), cv2.COLOR_BGR2RGB)
glass_array=cv2.cvtColor(glass_array,cv2.COLOR_RGB2BGR)
glass_array.shape
# Out:
# (1080, 1920, 3)

# %%
len(glass_array)
# Out:
# 1080

# %%
plt.imshow(glass_array)
